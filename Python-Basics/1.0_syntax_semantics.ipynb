# %% [markdown]
# ### SYNTAX AND SEMANTICS

# %%
## syntax refers to the set of rules that defines the combination of symbols that are considered to be correctly structured
## programs in a language.

## syntax is about the correct arrangement of words and symbols in a code.

## semantics refers to the meaning or the interpretation of the symbols, characters and commands in a language. its about what the
## code is supposed to do when its run.

# %%
# Python is case sensistivity

# %%
name = "chandru"
Name = "M D"

print(name +' '+Name)

print(name)

print(Name)
# Out:
# chandru M D
# chandru
# M D

# %%
## Indention 

## Indentation in python is used to define the structure and hierarchy of the code.

## python uses indentation to defines the blocks of code. consistent use of spaces (commonly 4) or a TAB is required.

age = 90
if age >60:
    print("Senior citizen!!")

print(age)
# Out:
# Senior citizen!!
# 90

# %%
## COMMENTS

## single line comment

"""
the
sum of add
substraction

"""
# Out:
# '\nthe\nsum of add\nsubstraction\n\n'

# %%
## Line continuation

# %%
total = 1+2+3+4+\
55+67+90

print(total)
# Out:
# 222

# %%
## Multiple statement on a single line

# %%
x = 3;y = 107;z = x+y

# %%
print(z)
# Out:
# 110

# %%
## Semantics

name = "Chandru" ## this is a string
age = 24 ## this is a integer
print(name)
print(age)
# Out:
# Chandru
# 24

# %%
type(name)
# Out:
# str

# %%
type(age)
# Out:
# int

# %%
## Type inference

var = 10
print(type(var))

var = "Sweety"
print(type(var))
# Out:
# <class 'int'>
# <class 'str'>

# %%
age = 15
if age > 12:
print("Teen")
# Out:
#   Cell In[21], line 3
#     print("Teen")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
age = 15
if age > 12:
    print("Teen")
# Out:
# Teen

# %%
## Name error

a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 3
#       1 ## Name error
#       2
# ----> 3 a=b
#
# NameError: name 'b' is not defined

# %%
## Code example of indentation

if True:
    print("Correct indentation")
    if False:
        print("It Won't print the statement")
    print('This is will print')

print("This is outside of the statement")
# Out:
# Correct indentation
# This is will print
# This is outside of the statement
