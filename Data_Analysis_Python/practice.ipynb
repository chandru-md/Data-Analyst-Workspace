# %%
import numpy as np

# %%
arr1 = np.array([1,2,3,4,5])

# %%
print(arr1)
# Out:
# [1 2 3 4 5]

# %%
print(type(arr1))
# Out:
# <class 'numpy.ndarray'>

# %%
print(arr1.shape)
# Out:
# (5,)

# %%
arr1.reshape(1,5)
# Out:
# array([[1, 2, 3, 4, 5]])

# %%
arr1.reshape(5,1)
# Out:
# array([[1],
#        [2],
#        [3],
#        [4],
#        [5]])
