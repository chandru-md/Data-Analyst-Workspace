# %%
import pandas as pd

# %%
from io import StringIO
Data = '{"employee_name":"Chandru","email":"chandru@gmail.com","job_profile":["title1":"Team Lead", "title2":"Sr. Developer"]}'
pd.read_json(StringIO(Data))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 from io import StringIO
#       2 Data = '{"employee_name":"Chandru","email":"chandru@gmail.com","job_profile":["title1":"Team Lead", "title2":"Sr. Developer"]}'
# ----> 3 pd.read_json(StringIO(Data))
#
# File d:\Data_Analyst_Workspace\venv\Lib\site-packages\pandas\io\json\_json.py:853, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     851     return json_reader
#     852 else:
# --> 853     return json_reader.read()
#
# File d:\Data_Analyst_Workspace\venv\Lib\site-packages\pandas\io\json\_json.py:989, in JsonReader.read(self)
#     987         obj = self._read_pyarrow()
#     988     elif self.engine == "ujson":
# ...

# %%
from io import StringIO
import pandas as pd

Data = '{"employee_name":"Chandru","email":"chandru@gmail.com","job_profile":{"title1":"Team Lead","title2":"Sr. Developer"}}'
df = pd.read_json(StringIO(Data))
print(df)
# Out:
#        employee_name              email    job_profile
# title1       Chandru  chandru@gmail.com      Team Lead
# title2       Chandru  chandru@gmail.com  Sr. Developer

# %%
from io import StringIO
import pandas as pd

Data = '{"employee_name":"Chandru","email":"chandru@gmail.com","job_profile":[{"title":"Team Lead"},{"title":"Sr. Developer"}]}'
df = pd.read_json(StringIO(Data))
print(df)
# Out:
#   employee_name              email                 job_profile
# 0       Chandru  chandru@gmail.com      {'title': 'Team Lead'}
# 1       Chandru  chandru@gmail.com  {'title': 'Sr. Developer'}

# %%
df.to_json()
# Out:
# '{"employee_name":{"0":"Chandru","1":"Chandru"},"email":{"0":"chandru@gmail.com","1":"chandru@gmail.com"},"job_profile":{"0":{"title":"Team Lead"},"1":{"title":"Sr. Developer"}}}'

# %%
df.to_json(orient = "index")
# Out:
# '{"0":{"employee_name":"Chandru","email":"chandru@gmail.com","job_profile":{"title":"Team Lead"}},"1":{"employee_name":"Chandru","email":"chandru@gmail.com","job_profile":{"title":"Sr. Developer"}}}'

# %%
df.to_json(orient = "records")
# Out:
# '[{"employee_name":"Chandru","email":"chandru@gmail.com","job_profile":{"title":"Team Lead"}},{"employee_name":"Chandru","email":"chandru@gmail.com","job_profile":{"title":"Sr. Developer"}}]'

# %%
# df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data")

# %%
# !pip install lxml
# Out:
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ------- -------------------------------- 0.8/4.0 MB 4.8 MB/s eta 0:00:01
#    ------------------ --------------------- 1.8/4.0 MB 5.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.9/4.0 MB 4.9 MB/s eta 0:00:01
#    ------------------------------------ --- 3.7/4.0 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 4.7 MB/s  0:00:00
# ...

# %%
# !pip install html5lib
# Out:
# ...
#
#    ---------------------------------------- 0/2 [webencodings]
#    -------------------- ------------------- 1/2 [html5lib]
#    -------------------- ------------------- 1/2 [html5lib]
#    -------------------- ------------------- 1/2 [html5lib]
#    -------------------- ------------------- 1/2 [html5lib]
#    -------------------- ------------------- 1/2 [html5lib]
#    -------------------- ------------------- 1/2 [html5lib]
#    ---------------------------------------- 2/2 [html5lib]
#
# ...

# %%
# !pip install beautifulsoup4
# Out:
# ...
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# ...
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# ...
#
#    ------------- -------------------------- 1/3 [soupsieve]
#    ------------- -------------------------- 1/3 [soupsieve]
#    -------------------------- ------------- 2/3 [beautifulsoup4]
#    -------------------------- ------------- 2/3 [beautifulsoup4]
#    -------------------------- ------------- 2/3 [beautifulsoup4]
#    -------------------------- ------------- 2/3 [beautifulsoup4]
#    ---------------------------------------- 3/3 [beautifulsoup4]
#
# ...

# %%
url = "https://www.fdic.gov/bank-failures/failed-bank-list"

df = pd.read_html(url)

# %%
df
# Out:
# [                                            Bank Name                City  \
#  0                   Metropolitan Capital Bank & Trust             Chicago
#  1                        The Santa Anna National Bank          Santa Anna
#  2                                Pulaski Savings Bank             Chicago
#  3                  The First National Bank of Lindsay             Lindsay
#  4               Republic First Bank dba Republic Bank        Philadelphia
#  5                                       Citizens Bank            Sac City
#  6                            Heartland Tri-State Bank             Elkhart
#  7                                 First Republic Bank       San Francisco
#  8                                      Signature Bank            New York
#  9                                 Silicon Valley Bank         Santa Clara
#  10                                  Almena State Bank              Almena
# ...

# %%
df[0]
# Out:
#                                             Bank Name                City  \
# 0                   Metropolitan Capital Bank & Trust             Chicago
# 1                        The Santa Anna National Bank          Santa Anna
# 2                                Pulaski Savings Bank             Chicago
# 3                  The First National Bank of Lindsay             Lindsay
# 4               Republic First Bank dba Republic Bank        Philadelphia
# 5                                       Citizens Bank            Sac City
# 6                            Heartland Tri-State Bank             Elkhart
# 7                                 First Republic Bank       San Francisco
# 8                                      Signature Bank            New York
# 9                                 Silicon Valley Bank         Santa Clara
# 10                                  Almena State Bank              Almena
# 11                         First City Bank of Florida   Fort Walton Beach
# ...

# %%
url = "https://en.wikipedia.org/wiki/Mobile_country_code"

df = pd.read_html(url,match="Country",header=0)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 url = "https://en.wikipedia.org/wiki/Mobile_country_code"
#       2
# ----> 3 df = pd.read_html(url,match="Country",header=0)
#
# File d:\Data_Analyst_Workspace\venv\Lib\site-packages\pandas\io\html.py:1226, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1222 check_dtype_backend(dtype_backend)
#    1224 io = stringify_path(io)
# -> 1226 return _parse(
#    1227     flavor=flavor,
#    1228     io=io,
#    1229     match=match,
#    1230     header=header,
#    1231     index_col=index_col,
#    1232     skiprows=skiprows,
#    1233     parse_dates=parse_dates,
#    1234     thousands=thousands,
#    1235     attrs=attrs,
# ...

# %%
df_excel = pd.read_excel("D:\Data_Analyst_Workspace\Data_Analysis_Python\data1.xlsx")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\CHANDRU DEIVANAYAGAN\AppData\Local\Temp\ipykernel_952\1481736440.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df_excel = pd.read_excel("D:\Data_Analyst_Workspace\Data_Analysis_Python\data1.xlsx")

# %%
df_excel.to_pickle("df_excel_pickle")

# %%
pd.read_pickle("df_excel_pickle")
# Out:
#         name  age
# 0    chandru   24
# 1     lokesh   24
# 2  kadhirvel   24
# 3    razeeth   25
# 4       hari   25
